# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/personal-key-indicators-of-heart-disease/2020/heart_2020_cleaned.csv
# /kaggle/input/personal-key-indicators-of-heart-disease/2022/heart_2022_with_nans.csv
# /kaggle/input/personal-key-indicators-of-heart-disease/2022/heart_2022_no_nans.csv

# %%
df = pd.read_csv("/kaggle/input/personal-key-indicators-of-heart-disease/2022/heart_2022_no_nans.csv")

# %%
df.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 4.0               0.0
# 1  Alabama    Male     Very good                 0.0               0.0
# 2  Alabama    Male     Very good                 0.0               0.0
# 3  Alabama  Female          Fair                 5.0               0.0
# 4  Alabama  Female          Good                 3.0              15.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                Yes
# 1  Within past year (anytime less than 12 months ...                Yes
# 2  Within past year (anytime less than 12 months ...                 No
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours            RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246022 non-null  object
#  1   Sex                        246022 non-null  object
#  2   GeneralHealth              246022 non-null  object
#  3   PhysicalHealthDays         246022 non-null  float64
#  4   MentalHealthDays           246022 non-null  float64
#  5   LastCheckupTime            246022 non-null  object
#  6   PhysicalActivities         246022 non-null  object
#  7   SleepHours                 246022 non-null  float64
#  8   RemovedTeeth               246022 non-null  object
#  9   HadHeartAttack             246022 non-null  object
#  10  HadAngina                  246022 non-null  object
#  11  HadStroke                  246022 non-null  object
#  12  HadAsthma                  246022 non-null  object
# ...

# %%
df.drop(['RemovedTeeth','HadSkinCancer','DeafOrHardOfHearing','DeafOrHardOfHearing','DifficultyErrands','RaceEthnicityCategory'],axis =1,inplace = True)

# %%
df.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 4.0               0.0
# 1  Alabama    Male     Very good                 0.0               0.0
# 2  Alabama    Male     Very good                 0.0               0.0
# 3  Alabama  Female          Fair                 5.0               0.0
# 4  Alabama  Female          Good                 3.0              15.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                Yes
# 1  Within past year (anytime less than 12 months ...                Yes
# 2  Within past year (anytime less than 12 months ...                 No
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours HadHeartAttack HadAngina  ... HeightInMeters WeightInKilograms  \
# ...

# %%
df.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays     SleepHours  HeightInMeters  \
# count       246022.000000     246022.000000  246022.000000   246022.000000
# mean             4.119026          4.167140       7.021331        1.705150
# std              8.405844          8.102687       1.440681        0.106654
# min              0.000000          0.000000       1.000000        0.910000
# 25%              0.000000          0.000000       6.000000        1.630000
# 50%              0.000000          0.000000       7.000000        1.700000
# 75%              3.000000          4.000000       8.000000        1.780000
# max             30.000000         30.000000      24.000000        2.410000
#
#        WeightInKilograms            BMI
# count      246022.000000  246022.000000
# mean           83.615179      28.668136
# std            21.323156       6.513973
# min            28.120000      12.020000
# 25%            68.040000      24.270000
# 50%            81.650000      27.460000
# ...

# %%
df.isna().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# AgeCategory                  0
# HeightInMeters               0
# WeightInKilograms            0
# BMI                          0
# AlcoholDrinkers              0
# HIVTesting                   0
# ...

# %%
df.isnull().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# AgeCategory                  0
# HeightInMeters               0
# WeightInKilograms            0
# BMI                          0
# AlcoholDrinkers              0
# HIVTesting                   0
# ...

# %%
sns.jointplot(x = "Sex",y="HadHeartAttack",data=df,alpha = 0.5 )
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x = "SleepHours",y="HadHeartAttack",data=df,alpha = 0.5 )
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df,kind = "scatter",plot_kws={'alpha':0.4})
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df['HadHeartAttack'] = df['HadHeartAttack'].replace({'No': 0, 'Yes': 1})
# Out:
# /tmp/ipykernel_13/226134721.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadHeartAttack'] = df['HadHeartAttack'].replace({'No': 0, 'Yes': 1})

# %%
df.HadHeartAttack
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 246017    0
# 246018    0
# 246019    0
# 246020    0
# 246021    1
# Name: HadHeartAttack, Length: 246022, dtype: int64

# %%
df['HadHeartAttack'] = df['HadHeartAttack'].astype('category',copy = False)

# %%
df['HadHeartAttack'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='HadHeartAttack'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246022 non-null  object
#  1   Sex                        246022 non-null  object
#  2   GeneralHealth              246022 non-null  object
#  3   PhysicalHealthDays         246022 non-null  float64
#  4   MentalHealthDays           246022 non-null  float64
#  5   LastCheckupTime            246022 non-null  object
#  6   PhysicalActivities         246022 non-null  object
#  7   SleepHours                 246022 non-null  float64
#  8   HadHeartAttack             246022 non-null  category
#  9   HadAngina                  246022 non-null  object
#  10  HadStroke                  246022 non-null  object
#  11  HadAsthma                  246022 non-null  object
#  12  HadCOPD                    246022 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['State', 'Sex', 'GeneralHealth', 'PhysicalHealthDays',
#        'MentalHealthDays', 'LastCheckupTime', 'PhysicalActivities',
#        'SleepHours', 'HadHeartAttack', 'HadAngina', 'HadStroke', 'HadAsthma',
#        'HadCOPD', 'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'BlindOrVisionDifficulty', 'DifficultyConcentrating',
#        'DifficultyWalking', 'DifficultyDressingBathing', 'SmokerStatus',
#        'ECigaretteUsage', 'ChestScan', 'AgeCategory', 'HeightInMeters',
#        'WeightInKilograms', 'BMI', 'AlcoholDrinkers', 'HIVTesting',
#        'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap',
#        'HighRiskLastYear', 'CovidPos'],
#       dtype='object')

# %%
y = df.HadHeartAttack

# %%
x = df.drop('HadHeartAttack',axis = 1)

# %%
x
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 4.0
# 1              Alabama    Male     Very good                 0.0
# 2              Alabama    Male     Very good                 0.0
# 3              Alabama  Female          Fair                 5.0
# 4              Alabama  Female          Good                 3.0
# ...                ...     ...           ...                 ...
# 246017  Virgin Islands    Male     Very good                 0.0
# 246018  Virgin Islands  Female          Fair                 0.0
# 246019  Virgin Islands    Male          Good                 0.0
# 246020  Virgin Islands  Female     Excellent                 2.0
# 246021  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 246017    0
# 246018    0
# 246019    0
# 246020    0
# 246021    1
# Name: HadHeartAttack, Length: 246022, dtype: category
# Categories (2, int64): [0, 1]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
x2 = pd.get_dummies(x)

x2_train,x2_test,y_train,y_test = train_test_split(x2,y,test_size = 0.3,stratify = y,random_state = 42)

# %%
x2_train
# Out:
#         PhysicalHealthDays  MentalHealthDays  SleepHours  HeightInMeters  \
# 184108                 0.0               0.0         6.0            1.63
# 240699                 0.0               4.0         6.0            1.68
# 115741                 0.0               2.0         6.0            1.75
# 2455                   1.0               0.0         7.0            1.55
# 29177                  2.0               0.0         7.0            1.60
# ...                    ...               ...         ...             ...
# 81800                  0.0              20.0         8.0            1.73
# 230773                 0.0               0.0         6.0            1.80
# 58357                  0.0               0.0         8.0            1.63
# 60120                  2.0               0.0         6.0            1.57
# 168296                 0.0               0.0         7.0            1.65
#
#         WeightInKilograms    BMI  State_Alabama  State_Alaska  State_Arizona  \
# ...

# %%
x2_test
# Out:
#         PhysicalHealthDays  MentalHealthDays  SleepHours  HeightInMeters  \
# 170069                 3.0              10.0         7.0            1.83
# 197214                 0.0               0.0         7.0            1.65
# 210650                 2.0              10.0         7.0            1.68
# 211223                 0.0               0.0         7.0            1.80
# 195816                 1.0               0.0         8.0            1.60
# ...                    ...               ...         ...             ...
# 112422                 2.0               0.0         7.0            1.68
# 120728                30.0               3.0         5.0            1.70
# 121082                 0.0               0.0         7.0            1.83
# 42353                  2.0              28.0         6.0            1.78
# 15412                  3.0               0.0         7.0            1.80
#
#         WeightInKilograms    BMI  State_Alabama  State_Alaska  State_Arizona  \
# ...

# %%
y_train
# Out:
# 184108    0
# 240699    0
# 115741    0
# 2455      0
# 29177     0
#          ..
# 81800     0
# 230773    0
# 58357     1
# 60120     0
# 168296    0
# Name: HadHeartAttack, Length: 172215, dtype: category
# Categories (2, int64): [0, 1]

# %%
y_test
# Out:
# 170069    0
# 197214    0
# 210650    0
# 211223    0
# 195816    0
#          ..
# 112422    0
# 120728    1
# 121082    0
# 42353     0
# 15412     0
# Name: HadHeartAttack, Length: 73807, dtype: category
# Categories (2, int64): [0, 1]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x2_train,y_train)
y_pred = lr.predict(x2_test)
y_pred
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score , classification_report
accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy : {accuracy : .2f}")
print (classification_report(y_test,y_pred))
# Out:
# Accuracy :  0.95
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     69776
#            1       0.54      0.26      0.35      4031
#
#     accuracy                           0.95     73807
#    macro avg       0.75      0.62      0.66     73807
# weighted avg       0.94      0.95      0.94     73807
